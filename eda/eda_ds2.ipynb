# %%
import pandas as pd
df = pd.read_csv('datasets\\acquisitions.csv')
print(df.head(5))
# Out:
#    id  acquisition_id acquiring_object_id acquired_object_id term_code  \
# 0   1               1                c:11               c:10       NaN
# 1   2               7                c:59               c:72      cash
# 2   3               8                c:24              c:132      cash
# 3   4               9                c:59              c:155      cash
# 4   5              10               c:212              c:215      cash
#
#    price_amount price_currency_code acquired_at  \
# 0    20000000.0                 USD  2007-05-30
# 1    60000000.0                 USD  2007-07-01
# 2   280000000.0                 USD  2007-05-01
# 3   100000000.0                 USD  2007-06-01
# 4    25000000.0                 USD  2007-07-01
#
#                                           source_url  \
# 0  http://venturebeat.com/2007/05/30/fox-interact...
# 1  http://www.techcrunch.com/2007/07/02/deal-is-c...
# 2  http://www.techcrunch.com/2007/05/30/cbs-acqui...
# ...

# %%
df_degrees = pd.read_csv('datasets\\degrees.csv')
most_common_degrees = df_degrees['subject'].value_counts()
print(most_common_degrees)
# Out:
# subject
# Computer Science                                     6001
# Economics                                            3564
# Electrical Engineering                               2722
# Finance                                              2471
# Business Administration                              2161
#                                                      ...
# Chemical/Bio Engineering                                1
# Finance and Production & Operations                     1
# Intermediate French                                     1
# M.S. in chemical engineering                            1
# Business/Managerial Economics - Political Science       1
# Name: count, Length: 20050, dtype: int64

# %%
df_relationships = pd.read_csv('datasets\\relationships.csv')
print(df_relationships.head(5))
# Out:
#    id  relationship_id person_object_id relationship_object_id    start_at  \
# 0   1                1              p:2                    c:1         NaN
# 1   2                2              p:3                    c:1         NaN
# 2   3                3              p:4                    c:3         NaN
# 3   4                4              p:5                    c:3  2006-03-01
# 4   6                6              p:7                    c:4  2005-07-01
#
#        end_at  is_past  sequence                                title  \
# 0         NaN        0         8    Co-Founder/CEO/Board of Directors
# 1         NaN        1    279242                         VP Marketing
# 2         NaN        0         4                           Evangelist
# 3  2009-12-01        1         4  Senior Director Strategic Alliances
# 4  2010-04-05        1         1              Chief Executive Officer
#
#             created_at           updated_at
# 0  2007-05-25 07:03:54  2013-06-03 09:58:46
# ...

# %%
df_ipos = pd.read_csv('datasets\\ipos.csv')
print(df_ipos.head(40))
# Out:
#     id  ipo_id object_id  valuation_amount valuation_currency_code  \
# 0    1       1    c:1654      0.000000e+00                     USD
# 1    2       2    c:1242      0.000000e+00                     USD
# 2    3       3     c:342      0.000000e+00                     USD
# 3    4       4      c:59      0.000000e+00                     USD
# 4    5       5     c:317      1.000000e+11                     USD
# 5    6       6    c:1438      3.500000e+08                     USD
# 6    7       7    c:2644      1.600000e+08                     USD
# 7    8       8    c:2584      0.000000e+00                     USD
# 8    9       9    c:2720      0.000000e+00                     USD
# 9   10      11    c:3316      6.000000e+09                     USD
# 10  11      12    c:2537      0.000000e+00                     USD
# 11  12      13     c:475      2.350000e+08                     USD
# 12  13      14     c:283      0.000000e+00                     USD
# ...

# %%
df_milestones = pd.read_csv('datasets\\milestones.csv')
print(df_milestones.head(5))
# Out:
#    id object_id milestone_at milestone_code  \
# 0   1      c:12   2008-06-09          other
# 1   2    c:3138   2008-06-17          other
# 2   3      c:59   2008-06-18          other
# 3   4     c:314   2008-06-18          other
# 4   5     c:314   2008-01-22          other
#
#                                          description  \
# 0                       Survives iPhone 3G Stevenote
# 1  Twhirl announces support for Seesmic video pla...
# 2  More than 4 Billion videos viewed at Google Si...
# 3                            Reddit goes Open Source
# 4        Adds the ability to create your own Reddits
#
#                                           source_url  \
# 0  http://www.techcrunch.com/2008/06/10/twitter-f...
# 1  http://www.inquisitr.com/1103/seesmic-now-avai...
# 2  http://www.comscore.com/press/release.asp?pres...
# 3  http://blog.reddit.com/2008/06/reddit-goes-ope...
# 4  http://www.techcrunch.com/2008/01/22/reddit-ad...
#
# ...

# %%
df_a = pd.read_csv('datasets\\acquisitions.csv')
print(df_a.head(5))
# Out:
#    id  acquisition_id acquiring_object_id acquired_object_id term_code  \
# 0   1               1                c:11               c:10       NaN
# 1   2               7                c:59               c:72      cash
# 2   3               8                c:24              c:132      cash
# 3   4               9                c:59              c:155      cash
# 4   5              10               c:212              c:215      cash
#
#    price_amount price_currency_code acquired_at  \
# 0    20000000.0                 USD  2007-05-30
# 1    60000000.0                 USD  2007-07-01
# 2   280000000.0                 USD  2007-05-01
# 3   100000000.0                 USD  2007-06-01
# 4    25000000.0                 USD  2007-07-01
#
#                                           source_url  \
# 0  http://venturebeat.com/2007/05/30/fox-interact...
# 1  http://www.techcrunch.com/2007/07/02/deal-is-c...
# 2  http://www.techcrunch.com/2007/05/30/cbs-acqui...
# ...

# %%
df_funding_rounds = pd.read_csv('datasets\\funding_rounds.csv')
# Convert the date column to datetime
df_funding_rounds['created_at'] = pd.to_datetime(df_funding_rounds['created_at'])

# Get the minimum and maximum date
min_date = df_funding_rounds['created_at'].min()
max_date = df_funding_rounds['created_at'].max()

print(f"Date range: {min_date} to {max_date}")
# Out:
# Date range: 2007-05-27 06:08:18 to 2013-12-12 14:27:53

# %%
print(df_a.columns)
print(df_a['acquired_object_id'].head(5))
# Out:
# Index(['id', 'acquisition_id', 'acquiring_object_id', 'acquired_object_id',
#        'term_code', 'price_amount', 'price_currency_code', 'acquired_at',
#        'source_url', 'source_description', 'created_at', 'updated_at'],
#       dtype='object')
# 0     c:10
# 1     c:72
# 2    c:132
# 3    c:155
# 4    c:215
# Name: acquired_object_id, dtype: object
